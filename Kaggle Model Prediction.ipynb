# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import GridSearchCV

# %matplotlib inline

# %%
#EDA on data housing prices
df.shape
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-3-e17e8d3f5722> in <module>()
#       1 #EDA on data housing prices
# ----> 2 df.shape
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-4-95faa30ac5cd> in <module>()
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv('train.csv')
df.shape
pd.set_option('display.max.columns', 500)
pd.set_option('display.max.rows',2000)
df.head()
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
df.loc[df['Electrical'].isnull()==True]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1379  1380          80       RL         73.0     9735   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1379         Lvl    AllPub    Inside       Gtl       Timber       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1379       Norm     1Fam       SLvl            5            5       2006
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1379          2007     Gable  CompShg     VinylSd     VinylSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1379         0.0        TA        TA      PConc       Gd       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1379           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# ...

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
#sns.heatmap(df.corr(), annot=True) #This was a mistake LUL

# %%
df['OverallQual'].value_counts()
# Out:
# 5     397
# 6     374
# 7     319
# 8     168
# 4     116
# 9      43
# 3      20
# 10     18
# 2       3
# 1       2
# Name: OverallQual, dtype: int64

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
#Get dummies aspect

# %%
df['TotalSF'] = df['1stFlrSF'] + df['2ndFlrSF']
df['ExtraSF'] = df['WoodDeckSF'] + df['PoolArea'] + df['OpenPorchSF'] + df['EnclosedPorch'] + df['EnclosedPorch'] + df['ScreenPorch']
cols = ['OverallQual','SalePrice','GrLivArea','OverallCond','TotRmsAbvGrd','LotArea',
       'TotalBsmtSF','BsmtUnfSF','1stFlrSF','2ndFlrSF','GarageCars','TotalSF','YearBuilt','YearRemodAdd',
       'WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','YrSold','ExtraSF']


df_subset = df[cols]
df_subset.head()
# Out:
#    OverallQual  SalePrice  GrLivArea  OverallCond  TotRmsAbvGrd  LotArea  \
# 0            7     208500       1710            5             8     8450
# 1            6     181500       1262            8             6     9600
# 2            7     223500       1786            5             6    11250
# 3            7     140000       1717            5             7     9550
# 4            8     250000       2198            5             9    14260
#
#    TotalBsmtSF  BsmtUnfSF  1stFlrSF  2ndFlrSF  GarageCars  TotalSF  YearBuilt  \
# 0          856        150       856       854           2     1710       2003
# 1         1262        284      1262         0           2     1262       1976
# 2          920        434       920       866           2     1786       2001
# 3          756        540       961       756           3     1717       1915
# 4         1145        490      1145      1053           3     2198       2000
#
# ...

# %%
df_subset.isnull().sum()
# Out:
# OverallQual      0
# SalePrice        0
# GrLivArea        0
# OverallCond      0
# TotRmsAbvGrd     0
# LotArea          0
# TotalBsmtSF      0
# BsmtUnfSF        0
# 1stFlrSF         0
# 2ndFlrSF         0
# GarageCars       0
# TotalSF          0
# YearBuilt        0
# YearRemodAdd     0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# YrSold           0
# dtype: int64

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_subset.isnull().sum()
sns.pairplot(df_subset)

# %%
fig, ax = plt.subplots(figsize=(15,15))
ax = sns.heatmap(df_subset.corr(),annot=True)
plt.show()

# %%
df_test=pd.read_csv('test.csv')

# %%
df_test['ExtraSF'] = df_test['WoodDeckSF'] + df_test['PoolArea'] + df_test['OpenPorchSF'] +  df_test['EnclosedPorch'] + df_test['EnclosedPorch'] + df_test['ScreenPorch']
df_test['TotalSF'] = df_test['1stFlrSF'] + df_test['2ndFlrSF']
#df_test.loc[df_test['GarageCars'].isnull()==True, 'GarageCars']=0
#df_test.loc[df_test['GarageCars'].isnull()==True,:]
#df_test.loc[df_test['TotalBsmtSF'].isnull()==True, 'TotalBsmtSF']=0
#df_test.loc[df_test['TotalBsmtSF'].isnull()==True,:]

# %%
features = ['OverallQual','GrLivArea','TotRmsAbvGrd','LotArea','TotalBsmtSF',
           'GarageCars','OverallCond','TotalSF','YearBuilt','YearRemodAdd','ExtraSF']

# %%
y = df['SalePrice']
X = df[features]
X_test = df_test[features]

# %%
#check na values
X_test.isnull().sum()
# Out:
# OverallQual     0
# GrLivArea       0
# TotRmsAbvGrd    0
# LotArea         0
# TotalBsmtSF     0
# GarageCars      0
# OverallCond     0
# TotalSF         0
# YearBuilt       0
# YearRemodAdd    0
# ExtraSF         0
# dtype: int64

# %%
#Features Ply first then Scalar for fitting
pf = PolynomialFeatures(include_bias = False, degree = 3)
X = pf.fit_transform(X)

ss = StandardScaler()
X = ss.fit_transform(X)

# %%
#Transform for test data
X_test = pf.transform(X_test)
X_test = ss.transform(X_test)

# %%
model = ElasticNet()
model.fit(X,y)
print model.score(X,y)

pred_train = model.predict(X)
pred = model.predict(X_test)
# Out:
# 0.872170219454

# %%
plt.scatter(pred_train, (pred_train-y))
plt.hlines(y=0, xmin=pred.min(), xmax=pred.max())

# %%
#pd.DataFrame(model.coef_, columns=['Coefs'], index = features)

# %%
#only to go back instead of gridsearch if alpha is bigger than 1
df_pred = pd.DataFrame(pred)
df_pred.rename(columns={0:'SalePrice'},inplace=True)
df_pred.head()

df_1st_submission = pd.concat([df_test['Id'],df_pred['SalePrice']], axis =1)
df_1st_submission.describe()

df_1st_submission.loc[df_1st_submission['SalePrice'] < 0, 'SalePrice' ] = 0
df_1st_submission.describe()
df_1st_submission.to_csv('1st_submit_fixed.csv',columns=['Id','SalePrice'],index_label=False, index=False)

# %%
#Concatenate the ID column to the Salesprice test data

# ideas for alpha if close to 1 [.001, .009, .0099, .01, .011, .012, .02, .03, .1, 1, 2, 10, 100]
#
alphas = np.linspace(0,5,11)
print alphas
# Out:
# [ 0.   0.5  1.   1.5  2.   2.5  3.   3.5  4.   4.5  5. ]

# %%
params = {
    'alpha':alphas,
    'l1_ratio': [.1, .2, .3, .4, .5, .6, .7, .8, .9, 1]
    
}
gs = GridSearchCV(model, param_grid=params, cv=3, scoring='r2')
gs.fit(X, y)
print gs.best_params_
print gs.best_score_
pred_gs_train = gs.predict(X)
pred_gs = gs.predict(X_test)
# Out:
# {'alpha': 5.0, 'l1_ratio': 0.9}
# 0.858577638811

# %%
plt.scatter(pred_gs_train, (pred_gs_train-y))
plt.hlines(y=0, xmin=pred.min(), xmax=pred.max())

# %%
df_pred = pd.DataFrame(pred_gs)
df_pred.rename(columns={0:'SalePrice'},inplace=True)
df_pred.head()

df_1st_submission = pd.concat([df_test['Id'],df_pred['SalePrice']], axis =1)
df_1st_submission.describe()

df_1st_submission.loc[df_1st_submission['SalePrice'] < 0, 'SalePrice' ] = 0
df_1st_submission.describe()
df_1st_submission.to_csv('1st_submit_fixed.csv',columns=['Id','SalePrice'],index_label=False, index=False)

# %% [markdown]
# alphas = np.logspace(0,2,200)
# params = {'alpha':alphas}
# gs = GridSearchCV(model, param_grid=params, cv=3, scoring = 'r2')
# gs.fit(X, y)
# print gs.best_score
# print gs.best_params_
